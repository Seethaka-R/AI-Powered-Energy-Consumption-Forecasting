# %% [markdown]
# # 01 - Exploratory Data Analysis
#
# This notebook loads the raw dataset, generates it if needed, and inspects the energy consumption patterns.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

# %%
from data_loader import load_or_generate_dataset
from Preprocessing import preprocess_data

df = load_or_generate_dataset(PROJECT_ROOT / 'data/raw/energy_data.csv', generate_if_missing=True)
df.head()

# %%
df.info()

# %%
df.describe().T

# %%
clean_df = preprocess_data(df)
clean_df[['consumption_kwh', 'temperature_c', 'humidity_pct']].plot(subplots=True, figsize=(14, 8), title='Cleaned Time Series');
