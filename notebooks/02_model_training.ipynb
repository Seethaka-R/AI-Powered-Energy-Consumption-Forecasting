# %% [markdown]
# # 02 - Model Training
#
# This notebook runs the training and evaluation workflow in smaller steps for experimentation.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
SRC_DIR = PROJECT_ROOT / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

# %%
from data_loader import load_or_generate_dataset
from Preprocessing import preprocess_data
from feature_engineering import engineer_features
from model import train_model, evaluate_model, forecast_future

df = load_or_generate_dataset(PROJECT_ROOT / 'data/raw/energy_data.csv', generate_if_missing=True)
clean_df = preprocess_data(df)
feature_df = engineer_features(clean_df)
model, X_train, X_test, y_train, y_test, feature_cols = train_model(feature_df)

# %%
metrics, y_pred = evaluate_model(model, X_test, y_test)
metrics

# %%
forecast_df = forecast_future(model, feature_df, feature_cols, days=30)
forecast_df.head()
